# %% [markdown]
# # User Based Collaborative Filtering

# %% [markdown]
# Technical Documents
#
# https://www.geeksforgeeks.org/user-based-collaborative-filtering/
#
# https://www.analyticsvidhya.com/blog/2022/02/introduction-to-collaborative-filtering/

# %% [markdown]
# ## Case Study - Movie Recommendation

# %% [markdown]
# A movie company wants to do user based recommendation with their dataset. The datasets includes 27,000 films and 2 million ratings. There are two dataset called movie and rating.
#
#
# Movie Variables:
# * title: Film name
# * movieId: Unique film number
#
# Rating Variables:
# * userId: Unique user id
# * movieId: Unique film number
# * rating: user rating
# * timestamp: Rate date

# %% [markdown]
# ### Step 1: Create user movie df and get random user

# %%
import pandas as pd

# %%
def create_user_movie_df():
    
    movie = pd.read_csv('movie.csv')
    rating = pd.read_csv('rating.csv')
    df = movie.merge(rating, on='movieId', how='left')
    comment_rating = pd.DataFrame(df['title'].value_counts())
    rare_movies = comment_rating[comment_rating['title'] <= 1000].index
    common_movies = df[~df['title'].isin(rare_movies)]
    user_movie_df = common_movies.pivot_table(index='userId', columns='title', values='rating')
    
    return user_movie_df

# %%
user_movie_df = create_user_movie_df()

# %%
user_movie_df.head(10)
# Out:
# title   'burbs, The (1989)  (500) Days of Summer (2009)  \
# userId
# 1.0                    NaN                          NaN
# 2.0                    NaN                          NaN
# 3.0                    NaN                          NaN
# 4.0                    NaN                          NaN
# 5.0                    NaN                          NaN
# 6.0                    NaN                          NaN
# 7.0                    NaN                          NaN
# 8.0                    NaN                          NaN
# 9.0                    NaN                          NaN
# 10.0                   NaN                          NaN
#
# title   *batteries not included (1987)  ...And Justice for All (1979)  \
# userId
# 1.0                                NaN                            NaN
# 2.0                                NaN                            NaN
# 3.0                                NaN                            NaN
# 4.0                                NaN                            NaN
# 5.0                                NaN                            NaN
# 6.0                                NaN                            NaN
# 7.0                                NaN                            NaN
# 8.0                                NaN                            NaN
# 9.0                                NaN                            NaN
# 10.0                               NaN                            NaN
#
# title   10 Things I Hate About You (1999)  10,000 BC (2008)  \
# userId
# 1.0                                   NaN               NaN
# 2.0                                   NaN               NaN
# 3.0                                   NaN               NaN
# 4.0                                   NaN               NaN
# 5.0                                   NaN               NaN
# 6.0                                   NaN               NaN
# 7.0                                   NaN               NaN
# 8.0                                   NaN               NaN
# 9.0                                   NaN               NaN
# 10.0                                  NaN               NaN
#
# title   101 Dalmatians (1996)  \
# userId
# 1.0                       NaN
# 2.0                       NaN
# 3.0                       NaN
# 4.0                       NaN
# 5.0                       NaN
# 6.0                       NaN
# 7.0                       NaN
# 8.0                       NaN
# 9.0                       NaN
# 10.0                      NaN
#
# title   101 Dalmatians (One Hundred and One Dalmatians) (1961)  \
# userId
# 1.0                                                   NaN
# 2.0                                                   NaN
# 3.0                                                   NaN
# 4.0                                                   NaN
# 5.0                                                   NaN
# 6.0                                                   NaN
# 7.0                                                   NaN
# 8.0                                                   NaN
# 9.0                                                   NaN
# 10.0                                                  NaN
#
# title   102 Dalmatians (2000)  12 Angry Men (1957)  ...  \
# userId                                              ...
# 1.0                       NaN                  NaN  ...
# 2.0                       NaN                  NaN  ...
# 3.0                       NaN                  NaN  ...
# 4.0                       NaN                  NaN  ...
# 5.0                       NaN                  NaN  ...
# 6.0                       NaN                  NaN  ...
# 7.0                       NaN                  NaN  ...
# 8.0                       NaN                  NaN  ...
# 9.0                       NaN                  NaN  ...
# 10.0                      NaN                  NaN  ...
#
# title   Zero Dark Thirty (2012)  Zero Effect (1998)  Zodiac (2007)  \
# userId
# 1.0                         NaN                 NaN            NaN
# 2.0                         NaN                 NaN            NaN
# 3.0                         NaN                 NaN            NaN
# 4.0                         NaN                 NaN            NaN
# 5.0                         NaN                 NaN            NaN
# 6.0                         NaN                 NaN            NaN
# 7.0                         NaN                 NaN            NaN
# 8.0                         NaN                 NaN            NaN
# 9.0                         NaN                 NaN            NaN
# 10.0                        NaN                 NaN            NaN
#
# title   Zombieland (2009)  Zoolander (2001)  Zulu (1964)  [REC] (2007)  \
# userId
# 1.0                   NaN               NaN          NaN           NaN
# 2.0                   NaN               NaN          NaN           NaN
# 3.0                   NaN               NaN          NaN           NaN
# 4.0                   NaN               NaN          NaN           NaN
# 5.0                   NaN               NaN          NaN           NaN
# 6.0                   NaN               NaN          NaN           NaN
# 7.0                   NaN               NaN          NaN           NaN
# 8.0                   NaN               NaN          NaN           NaN
# 9.0                   NaN               NaN          NaN           NaN
# 10.0                  NaN               NaN          NaN           NaN
#
# title   eXistenZ (1999)  xXx (2002)  ¡Three Amigos! (1986)
# userId
# 1.0                 NaN         NaN                    NaN
# 2.0                 NaN         NaN                    NaN
# 3.0                 NaN         NaN                    NaN
# 4.0                 NaN         NaN                    NaN
# 5.0                 NaN         NaN                    NaN
# 6.0                 NaN         NaN                    NaN
# 7.0                 NaN         NaN                    2.0
# 8.0                 NaN         NaN                    NaN
# 9.0                 NaN         NaN                    NaN
# 10.0                NaN         NaN                    NaN
#
# [10 rows x 3159 columns]

# %%
random_user = int(pd.Series(user_movie_df.index).sample(1, random_state=45).values)
random_user
# Out:
# 28941

# %% [markdown]
# ### Step 2: Get the watched films by random user

# %%
random_user_df = user_movie_df[user_movie_df.index == random_user]
random_user_df
# Out:
# title    'burbs, The (1989)  (500) Days of Summer (2009)  \
# userId
# 28941.0                 NaN                          NaN
#
# title    *batteries not included (1987)  ...And Justice for All (1979)  \
# userId
# 28941.0                             NaN                            NaN
#
# title    10 Things I Hate About You (1999)  10,000 BC (2008)  \
# userId
# 28941.0                                NaN               NaN
#
# title    101 Dalmatians (1996)  \
# userId
# 28941.0                    NaN
#
# title    101 Dalmatians (One Hundred and One Dalmatians) (1961)  \
# userId
# 28941.0                                                NaN
#
# title    102 Dalmatians (2000)  12 Angry Men (1957)  ...  \
# userId                                               ...
# 28941.0                    NaN                  NaN  ...
#
# title    Zero Dark Thirty (2012)  Zero Effect (1998)  Zodiac (2007)  \
# userId
# 28941.0                      NaN                 NaN            NaN
#
# title    Zombieland (2009)  Zoolander (2001)  Zulu (1964)  [REC] (2007)  \
# userId
# 28941.0                NaN               NaN          NaN           NaN
#
# title    eXistenZ (1999)  xXx (2002)  ¡Three Amigos! (1986)
# userId
# 28941.0              NaN         NaN                    NaN
#
# [1 rows x 3159 columns]

# %%
movie_watched = random_user_df.columns[random_user_df.notna().any()].tolist()
movie_watched
# Out:
# ['Ace Ventura: Pet Detective (1994)',
#  'Ace Ventura: When Nature Calls (1995)',
#  'Aladdin (1992)',
#  'American President, The (1995)',
#  'Apollo 13 (1995)',
#  'Babe (1995)',
#  'Bullets Over Broadway (1994)',
#  'Clueless (1995)',
#  'Disclosure (1994)',
#  'Forrest Gump (1994)',
#  'Four Weddings and a Funeral (1994)',
#  'Home Alone (1990)',
#  'Jurassic Park (1993)',
#  'Like Water for Chocolate (Como agua para chocolate) (1992)',
#  'Little Women (1994)',
#  "Mr. Holland's Opus (1995)",
#  'Mrs. Doubtfire (1993)',
#  'Much Ado About Nothing (1993)',
#  "Muriel's Wedding (1994)",
#  'Nine Months (1995)',
#  'Operation Dumbo Drop (1995)',
#  'Piano, The (1993)',
#  'Postman, The (Postino, Il) (1994)',
#  'Ready to Wear (Pret-A-Porter) (1994)',
#  'Remains of the Day, The (1993)',
#  'Sabrina (1995)',
#  "Schindler's List (1993)",
#  'Secret Garden, The (1993)',
#  'Sense and Sensibility (1995)',
#  'Shadowlands (1993)',
#  'Silence of the Lambs, The (1991)',
#  'Star Trek: Generations (1994)',
#  'Stargate (1994)']

# %%
len(movie_watched)
# Out:
# 33

# %% [markdown]
# ### Step 3: Other users wahtching the same movies

# %%
movie_watched_df = user_movie_df[movie_watched]
movie_watched_df
# Out:
# title     Ace Ventura: Pet Detective (1994)  \
# userId
# 1.0                                     NaN
# 2.0                                     NaN
# 3.0                                     NaN
# 4.0                                     NaN
# 5.0                                     NaN
# ...                                     ...
# 138489.0                                NaN
# 138490.0                                NaN
# 138491.0                                NaN
# 138492.0                                NaN
# 138493.0                                4.0
#
# title     Ace Ventura: When Nature Calls (1995)  Aladdin (1992)  \
# userId
# 1.0                                         NaN             NaN
# 2.0                                         NaN             NaN
# 3.0                                         NaN             NaN
# 4.0                                         3.0             NaN
# 5.0                                         NaN             5.0
# ...                                         ...             ...
# 138489.0                                    NaN             NaN
# 138490.0                                    NaN             NaN
# 138491.0                                    NaN             NaN
# 138492.0                                    NaN             NaN
# 138493.0                                    4.0             4.5
#
# title     American President, The (1995)  Apollo 13 (1995)  Babe (1995)  \
# userId
# 1.0                                  NaN               NaN          NaN
# 2.0                                  NaN               NaN          NaN
# 3.0                                  NaN               NaN          NaN
# 4.0                                  NaN               NaN          NaN
# 5.0                                  5.0               5.0          NaN
# ...                                  ...               ...          ...
# 138489.0                             NaN               NaN          NaN
# 138490.0                             NaN               4.0          5.0
# 138491.0                             NaN               NaN          NaN
# 138492.0                             NaN               NaN          NaN
# 138493.0                             NaN               4.5          3.0
#
# title     Bullets Over Broadway (1994)  Clueless (1995)  Disclosure (1994)  \
# userId
# 1.0                                NaN              NaN                NaN
# 2.0                                NaN              NaN                NaN
# 3.0                                NaN              NaN                NaN
# 4.0                                NaN              NaN                NaN
# 5.0                                NaN              NaN                NaN
# ...                                ...              ...                ...
# 138489.0                           NaN              NaN                NaN
# 138490.0                           NaN              NaN                NaN
# 138491.0                           NaN              NaN                NaN
# 138492.0                           NaN              NaN                NaN
# 138493.0                           NaN              NaN                NaN
#
# title     Forrest Gump (1994)  ...  Ready to Wear (Pret-A-Porter) (1994)  \
# userId                         ...
# 1.0                       NaN  ...                                   NaN
# 2.0                       NaN  ...                                   NaN
# 3.0                       NaN  ...                                   NaN
# 4.0                       4.0  ...                                   NaN
# 5.0                       NaN  ...                                   NaN
# ...                       ...  ...                                   ...
# 138489.0                  NaN  ...                                   NaN
# 138490.0                  NaN  ...                                   NaN
# 138491.0                  NaN  ...                                   NaN
# 138492.0                  NaN  ...                                   NaN
# 138493.0                  5.0  ...                                   NaN
#
# title     Remains of the Day, The (1993)  Sabrina (1995)  \
# userId
# 1.0                                  NaN             NaN
# 2.0                                  NaN             NaN
# 3.0                                  NaN             NaN
# 4.0                                  NaN             NaN
# 5.0                                  3.0             NaN
# ...                                  ...             ...
# 138489.0                             NaN             NaN
# 138490.0                             NaN             NaN
# 138491.0                             NaN             NaN
# 138492.0                             NaN             NaN
# 138493.0                             NaN             NaN
#
# title     Schindler's List (1993)  Secret Garden, The (1993)  \
# userId
# 1.0                           NaN                        NaN
# 2.0                           NaN                        NaN
# 3.0                           NaN                        NaN
# 4.0                           NaN                        3.0
# 5.0                           NaN                        5.0
# ...                           ...                        ...
# 138489.0                      NaN                        NaN
# 138490.0                      NaN                        4.0
# 138491.0                      NaN                        NaN
# 138492.0                      NaN                        NaN
# 138493.0                      5.0                        NaN
#
# title     Sense and Sensibility (1995)  Shadowlands (1993)  \
# userId
# 1.0                                NaN                 NaN
# 2.0                                NaN                 NaN
# 3.0                                NaN                 NaN
# 4.0                                NaN                 NaN
# 5.0                                3.0                 NaN
# ...                                ...                 ...
# 138489.0                           NaN                 NaN
# 138490.0                           4.0                 NaN
# 138491.0                           NaN                 NaN
# 138492.0                           NaN                 NaN
# 138493.0                           NaN                 NaN
#
# title     Silence of the Lambs, The (1991)  Star Trek: Generations (1994)  \
# userId
# 1.0                                    3.5                            NaN
# 2.0                                    NaN                            NaN
# 3.0                                    5.0                            5.0
# 4.0                                    NaN                            3.0
# 5.0                                    3.0                            NaN
# ...                                    ...                            ...
# 138489.0                               4.0                            NaN
# 138490.0                               5.0                            NaN
# 138491.0                               NaN                            NaN
# 138492.0                               NaN                            NaN
# 138493.0                               NaN                            NaN
#
# title     Stargate (1994)
# userId
# 1.0                   NaN
# 2.0                   NaN
# 3.0                   5.0
# 4.0                   NaN
# 5.0                   4.0
# ...                   ...
# 138489.0              NaN
# 138490.0              NaN
# 138491.0              NaN
# 138492.0              NaN
# 138493.0              NaN
#
# [138493 rows x 33 columns]

# %%
user_movie_count = movie_watched_df.T.notnull().sum()
user_movie_count
# Out:
# userId
# 1.0          1
# 2.0          2
# 3.0          4
# 4.0          6
# 5.0         11
#             ..
# 138489.0     1
# 138490.0     7
# 138491.0     0
# 138492.0     2
# 138493.0     9
# Length: 138493, dtype: int64

# %%
user_movie_count = user_movie_count.reset_index()
user_movie_count
# Out:
#           userId   0
# 0            1.0   1
# 1            2.0   2
# 2            3.0   4
# 3            4.0   6
# 4            5.0  11
# ...          ...  ..
# 138488  138489.0   1
# 138489  138490.0   7
# 138490  138491.0   0
# 138491  138492.0   2
# 138492  138493.0   9
#
# [138493 rows x 2 columns]

# %%
user_movie_count.columns = ['userId', 'movie_count']
user_movie_count.head()
# Out:
#    userId  movie_count
# 0     1.0            1
# 1     2.0            2
# 2     3.0            4
# 3     4.0            6
# 4     5.0           11

# %%
user_movie_count[user_movie_count['movie_count'] > 20].sort_values('movie_count', ascending=False)
# Out:
#           userId  movie_count
# 94230    94231.0           33
# 100398  100399.0           33
# 118204  118205.0           33
# 15918    15919.0           33
# 124051  124052.0           33
# ...          ...          ...
# 79214    79215.0           21
# 79174    79175.0           21
# 9105      9106.0           21
# 78515    78516.0           21
# 129        130.0           21
#
# [3202 rows x 2 columns]

# %%
user_same_movies = user_movie_count[user_movie_count['movie_count'] > 20]['userId']
user_same_movies.head()
# Out:
# 129    130.0
# 155    156.0
# 157    158.0
# 183    184.0
# 294    295.0
# Name: userId, dtype: float64

# %% [markdown]
# ### Step 4: Determination of similarity

# %% [markdown]
# **Concatenate random user and other users wahtching the same movies**

# %%
final_df = pd.concat([movie_watched_df[movie_watched_df.index.isin(user_same_movies)],
                    random_user_df[movie_watched]])

final_df
# Out:
# title     Ace Ventura: Pet Detective (1994)  \
# userId
# 130.0                                   4.0
# 156.0                                   3.0
# 158.0                                   2.0
# 184.0                                   2.0
# 295.0                                   NaN
# ...                                     ...
# 138279.0                                3.0
# 138382.0                                1.0
# 138415.0                                1.0
# 138483.0                                1.0
# 28941.0                                 3.0
#
# title     Ace Ventura: When Nature Calls (1995)  Aladdin (1992)  \
# userId
# 130.0                                       3.0             NaN
# 156.0                                       NaN             NaN
# 158.0                                       1.0             4.0
# 184.0                                       3.0             3.0
# 295.0                                       NaN             3.0
# ...                                         ...             ...
# 138279.0                                    NaN             NaN
# 138382.0                                    1.0             4.0
# 138415.0                                    NaN             3.0
# 138483.0                                    1.0             3.0
# 28941.0                                     2.0             2.0
#
# title     American President, The (1995)  Apollo 13 (1995)  Babe (1995)  \
# userId
# 130.0                                3.0               3.0          NaN
# 156.0                                5.0               5.0          3.0
# 158.0                                4.0               3.0          5.0
# 184.0                                4.0               4.0          NaN
# 295.0                                3.0               3.0          3.0
# ...                                  ...               ...          ...
# 138279.0                             3.0               5.0          5.0
# 138382.0                             2.0               3.0          5.0
# 138415.0                             4.0               3.0          5.0
# 138483.0                             3.0               3.0          NaN
# 28941.0                              3.0               3.0          5.0
#
# title     Bullets Over Broadway (1994)  Clueless (1995)  Disclosure (1994)  \
# userId
# 130.0                              NaN              3.0                5.0
# 156.0                              NaN              NaN                4.0
# 158.0                              NaN              4.0                NaN
# 184.0                              3.0              NaN                4.0
# 295.0                              3.0              2.0                NaN
# ...                                ...              ...                ...
# 138279.0                           5.0              4.0                NaN
# 138382.0                           NaN              4.0                3.0
# 138415.0                           NaN              NaN                NaN
# 138483.0                           3.0              3.0                2.0
# 28941.0                            4.0              5.0                3.0
#
# title     Forrest Gump (1994)  ...  Ready to Wear (Pret-A-Porter) (1994)  \
# userId                         ...
# 130.0                     5.0  ...                                   NaN
# 156.0                     5.0  ...                                   NaN
# 158.0                     5.0  ...                                   NaN
# 184.0                     3.0  ...                                   NaN
# 295.0                     4.0  ...                                   NaN
# ...                       ...  ...                                   ...
# 138279.0                  5.0  ...                                   NaN
# 138382.0                  5.0  ...                                   NaN
# 138415.0                  4.0  ...                                   NaN
# 138483.0                  4.0  ...                                   3.0
# 28941.0                   3.0  ...                                   3.0
#
# title     Remains of the Day, The (1993)  Sabrina (1995)  \
# userId
# 130.0                                3.0             NaN
# 156.0                                NaN             4.0
# 158.0                                5.0             3.0
# 184.0                                4.0             4.0
# 295.0                                3.0             3.0
# ...                                  ...             ...
# 138279.0                             5.0             NaN
# 138382.0                             NaN             3.0
# 138415.0                             5.0             NaN
# 138483.0                             4.0             NaN
# 28941.0                              5.0             5.0
#
# title     Schindler's List (1993)  Secret Garden, The (1993)  \
# userId
# 130.0                         5.0                        NaN
# 156.0                         5.0                        NaN
# 158.0                         5.0                        5.0
# 184.0                         5.0                        4.0
# 295.0                         4.0                        3.0
# ...                           ...                        ...
# 138279.0                      5.0                        NaN
# 138382.0                      NaN                        3.0
# 138415.0                      5.0                        3.0
# 138483.0                      4.0                        3.0
# 28941.0                       5.0                        3.0
#
# title     Sense and Sensibility (1995)  Shadowlands (1993)  \
# userId
# 130.0                              NaN                 3.0
# 156.0                              4.0                 4.0
# 158.0                              4.0                 5.0
# 184.0                              NaN                 4.0
# 295.0                              4.0                 NaN
# ...                                ...                 ...
# 138279.0                           4.0                 NaN
# 138382.0                           3.0                 NaN
# 138415.0                           4.0                 4.0
# 138483.0                           4.0                 4.0
# 28941.0                            5.0                 5.0
#
# title     Silence of the Lambs, The (1991)  Star Trek: Generations (1994)  \
# userId
# 130.0                                  5.0                            NaN
# 156.0                                  5.0                            3.0
# 158.0                                  5.0                            NaN
# 184.0                                  5.0                            3.0
# 295.0                                  4.0                            3.0
# ...                                    ...                            ...
# 138279.0                               5.0                            3.0
# 138382.0                               5.0                            NaN
# 138415.0                               NaN                            3.0
# 138483.0                               4.0                            2.0
# 28941.0                                1.0                            1.0
#
# title     Stargate (1994)
# userId
# 130.0                 3.0
# 156.0                 4.0
# 158.0                 NaN
# 184.0                 4.0
# 295.0                 2.0
# ...                   ...
# 138279.0              3.0
# 138382.0              4.0
# 138415.0              NaN
# 138483.0              2.0
# 28941.0               1.0
#
# [3203 rows x 33 columns]

# %% [markdown]
# **Transpoze dataframe to calculate correlation**

# %%
corr_df = final_df.T.corr().unstack().sort_values().drop_duplicates()

# %%
corr_df.head()
# Out:
# userId    userId
# 28866.0   67756.0   -0.936065
# 60562.0   37121.0   -0.915003
# 34103.0   80593.0   -0.898718
# 62575.0   21398.0   -0.896612
# 117826.0  48416.0   -0.883969
# dtype: float64

# %%
corr_df = pd.DataFrame(corr_df, columns=['corr'])
corr_df.head()
# Out:
#                       corr
# userId   userId
# 28866.0  67756.0 -0.936065
# 60562.0  37121.0 -0.915003
# 34103.0  80593.0 -0.898718
# 62575.0  21398.0 -0.896612
# 117826.0 48416.0 -0.883969

# %%
corr_df.index.names = ['userId1', 'userId2']
corr_df.head()
# Out:
#                       corr
# userId1  userId2
# 28866.0  67756.0 -0.936065
# 60562.0  37121.0 -0.915003
# 34103.0  80593.0 -0.898718
# 62575.0  21398.0 -0.896612
# 117826.0 48416.0 -0.883969

# %%
corr_df.reset_index(inplace=True)

# %%
corr_df.head()
# Out:
#     userId1  userId2      corr
# 0   28866.0  67756.0 -0.936065
# 1   60562.0  37121.0 -0.915003
# 2   34103.0  80593.0 -0.898718
# 3   62575.0  21398.0 -0.896612
# 4  117826.0  48416.0 -0.883969

# %%
top_users = corr_df[(corr_df['userId1'] == random_user) & (corr_df['corr'] >= 0.65)][['userId2', 'corr']].reset_index(drop=True)

# %%
top_users = top_users.sort_values('corr', ascending=False)
top_users.head()
# Out:
#       userId      corr
# 27   28941.0  1.000000
# 26   45158.0  0.800749
# 25  101628.0  0.790405
# 24  127259.0  0.763925
# 23    9783.0  0.747942

# %%
top_users.rename(columns = {'userId2': 'userId'}, inplace=True)
top_users.head()
# Out:
#       userId      corr
# 27   28941.0  1.000000
# 26   45158.0  0.800749
# 25  101628.0  0.790405
# 24  127259.0  0.763925
# 23    9783.0  0.747942

# %%
rating = pd.read_csv('rating.csv')

# %%
rating.head()
# Out:
#    userId  movieId  rating            timestamp
# 0       1        2     3.5  2005-04-02 23:53:47
# 1       1       29     3.5  2005-04-02 23:31:16
# 2       1       32     3.5  2005-04-02 23:33:39
# 3       1       47     3.5  2005-04-02 23:32:07
# 4       1       50     3.5  2005-04-02 23:29:40

# %%
top_users_rating = top_users.merge(rating[['userId', 'movieId', 'rating']], how='inner')
top_users_rating.head()
# Out:
#     userId  corr  movieId  rating
# 0  28941.0   1.0        7     5.0
# 1  28941.0   1.0       11     3.0
# 2  28941.0   1.0       17     5.0
# 3  28941.0   1.0       19     2.0
# 4  28941.0   1.0       34     5.0

# %%
top_users_rating = top_users_rating[top_users_rating['userId'] != random_user]
top_users_rating.head()
# Out:
#      userId      corr  movieId  rating
# 33  45158.0  0.800749        1     1.5
# 34  45158.0  0.800749        3     1.0
# 35  45158.0  0.800749       17     3.5
# 36  45158.0  0.800749       19     2.0
# 37  45158.0  0.800749       22     3.0

# %%
top_users_rating
# Out:
#          userId      corr  movieId  rating
# 33      45158.0  0.800749        1     1.5
# 34      45158.0  0.800749        3     1.0
# 35      45158.0  0.800749       17     3.5
# 36      45158.0  0.800749       19     2.0
# 37      45158.0  0.800749       22     3.0
# ...         ...       ...      ...     ...
# 13680  132307.0  0.660726      593     4.0
# 13681  132307.0  0.660726      595     4.0
# 13682  132307.0  0.660726      597     4.0
# 13683  132307.0  0.660726      608     5.0
# 13684  132307.0  0.660726     1084     3.0
#
# [13652 rows x 4 columns]

# %% [markdown]
# ### Step 5: Weighted Average Recomendations Score Calculation

# %%
top_users_rating['weighted_rating'] = top_users_rating['corr'] * top_users_rating['rating']
top_users_rating.head()
# Out:
#      userId      corr  movieId  rating  weighted_rating
# 33  45158.0  0.800749        1     1.5         1.201124
# 34  45158.0  0.800749        3     1.0         0.800749
# 35  45158.0  0.800749       17     3.5         2.802622
# 36  45158.0  0.800749       19     2.0         1.601498
# 37  45158.0  0.800749       22     3.0         2.402248

# %%
top_users_rating.groupby('movieId').agg({'weighted_rating': 'mean'})
# Out:
#          weighted_rating
# movieId
# 1               2.205824
# 2               1.463950
# 3               1.181772
# 4               1.642769
# 5               1.151408
# ...                  ...
# 56367           2.565300
# 56508           2.931772
# 56788           2.565300
# 58303           2.931772
# 59725           2.931772
#
# [4074 rows x 1 columns]

# %%
recommendation_movies = top_users_rating.groupby('movieId').agg({'weighted_rating': 'mean'})
recommendation_movies.head()
# Out:
#          weighted_rating
# movieId
# 1               2.205824
# 2               1.463950
# 3               1.181772
# 4               1.642769
# 5               1.151408

# %%
recommendation_movies.reset_index(inplace=True)

# %%
recommendation_movies.head()
# Out:
#    movieId  weighted_rating
# 0        1         2.205824
# 1        2         1.463950
# 2        3         1.181772
# 3        4         1.642769
# 4        5         1.151408

# %%
movies_to_be_recommend = recommendation_movies[recommendation_movies['weighted_rating'] > 3.5].\
                        sort_values('weighted_rating', ascending=False)

# %%
movies_to_be_recommend
# Out:
#       movieId  weighted_rating
# 26         30         3.952023
# 257       326         3.952023
# 183       242         3.952023
# 45         53         3.952023
# 920      1348         3.692678
# 394       501         3.679739
# 3873    25850         3.664714
# 3691     8128         3.664714
# 3907    26394         3.664714
# 3622     7585         3.664714
# 3610     7490         3.664714
# 3548     7215         3.664714
# 3502     7087         3.664714
# 3410     6837         3.664714
# 3195     6235         3.664714
# 3183     6216         3.664714
# 3064     5799         3.664714
# 2752     4920         3.664714
# 2721     4840         3.664714
# 2563     4495         3.664714
# 2396     4117         3.664714
# 3966    32234         3.664714
# 3121     5992         3.657336
# 201       263         3.649974
# 2482     4334         3.642581
# 3420     6870         3.642581
# 3439     6954         3.642581
# 3445     6974         3.642581
# 1578     2570         3.642581
# 1543     2496         3.642581
# 799      1201         3.642581
# 848      1257         3.603372
# 2636     4641         3.536131
# 1780     2943         3.510809

# %%
movie = pd.read_csv('movie.csv')
movie.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
movies_to_be_recommend.merge(movie[['movieId', 'title']], how='inner')
# Out:
#     movieId  weighted_rating  \
# 0        30         3.952023
# 1       326         3.952023
# 2       242         3.952023
# 3        53         3.952023
# 4      1348         3.692678
# 5       501         3.679739
# 6     25850         3.664714
# 7      8128         3.664714
# 8     26394         3.664714
# 9      7585         3.664714
# 10     7490         3.664714
# 11     7215         3.664714
# 12     7087         3.664714
# 13     6837         3.664714
# 14     6235         3.664714
# 15     6216         3.664714
# 16     5799         3.664714
# 17     4920         3.664714
# 18     4840         3.664714
# 19     4495         3.664714
# 20     4117         3.664714
# 21    32234         3.664714
# 22     5992         3.657336
# 23      263         3.649974
# 24     4334         3.642581
# 25     6870         3.642581
# 26     6954         3.642581
# 27     6974         3.642581
# 28     2570         3.642581
# 29     2496         3.642581
# 30     1201         3.642581
# 31     1257         3.603372
# 32     4641         3.536131
# 33     2943         3.510809
#
#                                                 title
# 0   Shanghai Triad (Yao a yao yao dao waipo qiao) ...
# 1                             To Live (Huozhe) (1994)
# 2                       Farinelli: il castrato (1994)
# 3                                     Lamerica (1994)
# 4   Nosferatu (Nosferatu, eine Symphonie des Graue...
# 5                                        Naked (1993)
# 6                                      Holiday (1938)
# 7                        Au revoir les enfants (1987)
# 8                           Turning Point, The (1977)
# 9                                   Summertime (1955)
# 10  At First Sight (Entre Nous) (Coup de foudre) (...
# 11                        To Have and Have Not (1944)
# 12                         Passage to India, A (1984)
# 13                                 Love Affair (1939)
# 14         Europa Europa (Hitlerjunge Salomon) (1990)
# 15     Nowhere in Africa (Nirgendwo in Afrika) (2001)
# 16                                      Exodus (1960)
# 17                                Now, Voyager (1942)
# 18         Last Metro, The (Dernier métro, Le) (1980)
# 19                           Crossing Delancey (1988)
# 20                              Hope and Glory (1987)
# 21                                       Julia (1977)
# 22                                  Hours, The (2002)
# 23                           Ladybird Ladybird (1994)
# 24                                       Yi Yi (2000)
# 25                                Mystic River (2003)
# 26  Barbarian Invasions, The (Les invasions barbar...
# 27                               Freshman, The (1990)
# 28                         Walk on the Moon, A (1999)
# 29                         Blast from the Past (1999)
# 30  Good, the Bad and the Ugly, The (Buono, il bru...
# 31                          Better Off Dead... (1985)
# 32                                 Ghost World (2001)
# 33                                   Indochine (1992)

# %% [markdown]
# ### Step 6: Functionalize all steps

# %%
def create_user_movie_df():
    
    movie = pd.read_csv('movie.csv')
    rating = pd.read_csv('rating.csv')
    df = movie.merge(rating, on='movieId', how='left')
    comment_rating = pd.DataFrame(df['title'].value_counts())
    rare_movies = comment_rating[comment_rating['title'] <= 1000].index
    common_movies = df[~df['title'].isin(rare_movies)]
    user_movie_df = common_movies.pivot_table(index='userId', columns='title', values='rating')
    
    return user_movie_df

# %%
def user_based_recommend(random_user, user_movie_df, ratio=60, corr_th=0.65, score=3.5):
    
    # Create random users df
    random_user_df = user_movie_df[user_movie_df.index == random_user]
    
    # Watched movie by random user
    movie_watched = random_user_df.columns[random_user_df.notna().any()].tolist()
    
    # Other users watching same movies
    movie_watched_df = user_movie_df[movie_watched]
    user_movie_count = movie_watched_df.T.notnull().sum()
    user_movie_count = user_movie_count.reset_index()
    user_movie_count.columns = ['userId', 'movie_count']
    perc = len(movie_watched) * ratio / 100
    user_same_movies = user_movie_count[user_movie_count['movie_count'] > perc]['userId']
    
    # Determination similarity
    final_df = pd.concat([movie_watched_df[movie_watched_df.index.isin(user_same_movies)],
                    random_user_df[movie_watched]])
    corr_df = final_df.T.corr().unstack().sort_values().drop_duplicates()
    corr_df = pd.DataFrame(corr_df, columns=['corr'])
    corr_df.index.names = ['userId1', 'userId2']
    corr_df.reset_index(inplace=True)
    top_users = corr_df[(corr_df['userId1'] == random_user) & (corr_df['corr'] >= corr_th)][['userId2', 'corr']].reset_index(drop=True)
    top_users = top_users.sort_values('corr', ascending=False)
    top_users.rename(columns = {'userId2': 'userId'}, inplace=True)
    rating = pd.read_csv('rating.csv')
    top_users_rating = top_users.merge(rating[['userId', 'movieId', 'rating']], how='inner')
    top_users_rating = top_users_rating[top_users_rating['userId'] != random_user]
    
    # Weighted average recomendations score calculation
    top_users_rating['weighted_rating'] = top_users_rating['corr'] * top_users_rating['rating']
    top_users_rating.groupby('movieId').agg({'weighted_rating': 'mean'})
    recommendation_movies = top_users_rating.groupby('movieId').agg({'weighted_rating': 'mean'})
    recommendation_movies.reset_index(inplace=True)
    movies_to_be_recommend = recommendation_movies[recommendation_movies['weighted_rating'] > score].\
                        sort_values('weighted_rating', ascending=False)
    movie = pd.read_csv('movie.csv')
    return movies_to_be_recommend.merge(movie[['movieId', 'title']], how='inner')

# %%
random_user_2 = int(pd.Series(user_movie_df.index).sample(1).values)
random_user_2
# Out:
# 15700

# %%
user_based_recommend(random_user_2, user_movie_df, ratio=60, corr_th=0.65, score=3.5)
# Out:
#     movieId  weighted_rating  \
# 0      2249         3.602415
# 1      3881         3.602415
# 2    127441         3.602415
# 3    120815         3.602415
# 4    120813         3.602415
# 5    120811         3.602415
# 6    120807         3.602415
# 7    105835         3.602415
# 8    102974         3.602415
# 9    102672         3.602415
# 10   102469         3.602415
# 11   100617         3.602415
# 12    97908         3.602415
# 13    97673         3.602415
# 14    96821         3.602415
# 15    94931         3.602415
# 16    91134         3.602415
# 17    78162         3.602415
# 18    77966         3.602415
# 19    74791         3.602415
# 20    73266         3.602415
# 21    50740         3.602415
# 22    48626         3.602415
# 23     5095         3.602415
# 24   128366         3.602415
# 25    50658         3.522949
#
#                                                 title
# 0                               My Blue Heaven (1990)
# 1                     Phish: Bittersweet Motel (2000)
# 2                         Last Days in Vietnam (2014)
# 3      Patton Oswalt: Werewolves and Lollipops (2007)
# 4         Patton Oswalt: My Weakness Is Strong (2009)
# 5                   Patton Oswalt: Finest Hour (2011)
# 6                    John Mulaney: New In Town (2012)
# 7                                  Double, The (2013)
# 8                   Somebody Up There Likes Me (2012)
# 9                 New York: A Documentary Film (1999)
# 10                          Wish You Were Here (2012)
# 11        Patton Oswalt: No Reason to Complain (2004)
# 12                            Babysitters, The (2007)
# 13                                       56 Up (2012)
# 14            Perks of Being a Wallflower, The (2012)
# 15                             Take This Waltz (2011)
# 16                        My Week with Marilyn (2011)
# 17              Ricky Gervais Live 2: Politics (2004)
# 18                              Love the Beast (2009)
# 19   Town Called Panic, A (Panique au village) (2009)
# 20                             Youth in Revolt (2009)
# 21                                   Seven Up! (1964)
# 22  Once in a Lifetime: The Extraordinary Story of...
# 23                               Scotland, Pa. (2001)
# 24  Patton Oswalt: Tragedy Plus Comedy Equals Time...
# 25                                       49 Up (2005)
